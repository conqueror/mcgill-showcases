# %% [markdown]
# # Credit Risk Diagnostics Notebook
#
# This notebook reads artifact outputs from the script-first capstone pipeline.

# %%
from pathlib import Path
import pandas as pd
root = Path('..').resolve()
feature_types = pd.read_csv(root / 'artifacts/diagnostics/feature_type_summary.csv')
feature_types.head()

# %%
missingness = pd.read_csv(root / 'artifacts/eda/missingness_summary.csv')
missingness.head(10)
