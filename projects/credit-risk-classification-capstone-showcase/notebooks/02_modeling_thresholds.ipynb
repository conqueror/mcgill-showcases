# %% [markdown]
# # Credit Risk Modeling and Thresholds
#
# Use this notebook to interpret strategy and threshold artifacts for deployment decisions.

# %%
from pathlib import Path
import pandas as pd
root = Path('..').resolve()
strategies = pd.read_csv(root / 'artifacts/models/strategy_comparison.csv')
strategies

# %%
thresholds = pd.read_csv(root / 'artifacts/eval/threshold_analysis.csv')
thresholds
